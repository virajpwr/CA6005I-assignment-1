# %% [markdown]
# ### Query Likelihood model with laplace smoothing.
#
# - This notebook implements query likelhood model to calculate the probability of a document given a query, using frequencies of query terms withing documents to estimate this likelihood.

# %% [markdown]
# ## Read the documents and queries.
#  - The 1400 documents from the "cran.all.1400.xml" is read and a dictionary containing document id and document text is saved as a dictionary.
#  - The queries are also read in similar way and a dictionary with query id and the query is created as  a key-value pair.

# %%
# import necessary libraries

import xml.etree.ElementTree as ET
import csv
from tqdm import tqdm
 
# utilities
from collections import defaultdict
import re
import numpy as np
import pandas as pd
from copy import deepcopy
import os
from itertools import chain
import operator
# nltk
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize.treebank import (TreebankWordTokenizer, TreebankWordDetokenizer)
from string import punctuation
from nltk import PorterStemmer
from collections import Counter

import math
from functools import lru_cache
import numpy as np
import math
import operator
from tqdm import tqdm
import itertools
from collections import Counter
from dataclasses import dataclass
from math import log
import pickle
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from num2words import num2words
nltk.download('punkt', quiet=True)
nltk.download('stopwords', quiet=True)
# Out:
# True

# %%
''' 
The class ReadDocs parses the input .xml file and creates a dictionary with docid and text as key-value pairs.

The class ReadQueries parses the input .xml file and creates a dictionary with queryid and text as key-value pairs.
'''
class ReadDocs:
    def __init__(self, input_file):
        self.input_file = input_file
        self.split_tag = "</doc>"
        self.documents = []
        
    def load_split_docs(self):
        ''' 
        Read the file and split the documents based on the split_tag.

        return: list of documents
        '''
        with open(self.input_file, "r") as f:
            data = f.read()
        documents_raw = data.split(self.split_tag)
        self.documents = [doc.strip() + self.split_tag for doc in documents_raw if doc.strip()]
    
    def read_document(self):
        ''' 
        Read the documents using ElementTree and create a dictionary with docid and text as key-value pairs.
        
        return: dictionary with docid and text as key-value pairs
        '''
        self.doc_dict = {}
        for _, doc in enumerate(self.documents):
            try:
                root = ET.fromstring(f"<root>{doc}</root>")
                docno_element = root.find('.//docno')
                text = root.find('.//text')
                docno = docno_element.text.strip() if docno_element is not None and docno_element.text else "**NODATA**"
                text = text.text.strip() if text is not None and text.text else "**NODATA**"
                if text == "**NODATA**":
                    continue
                else:
                    text = text.replace("\n", " ").replace(" .", "")
                    self.doc_dict[int(docno)] = str(text)
            except ET.ParseError as e:
                continue
        return self.doc_dict

class ReadQueries:
    def __init__(self, input_file):
        self.input_file = input_file
        self.queries = []
    
    def load_split_query(self):
        '''Read the file and split the queries based on the split_tag.
        
        return: Dictionary of queryid and query text as key-value pair
        '''        
        with open(self.input_file, "r") as f:
            data = f.read()
        self.queries = data.split("</top>")
        self.queries = [query.strip() + "</top>" for query in self.queries if query.strip()]
        
    def index_queries(self):
        query_dict = {}
        for i, query in enumerate(self.queries):
            try:
                root = ET.fromstring(f"<root>{query}</root>")
                num = root.find('.//num').text.strip()
                title = root.find('.//title').text.strip()
                title = title.replace("\n", " ").replace(" .", "")
                query_dict[int(num)] = str(title)
            except ET.ParseError as e:
                continue
        return query_dict
    
def mapping(query, doc):        
    mappings = {}
    for key, value in query.items():
        for k, v in doc.items():
            doc_keys = list(doc.keys())
            doc_keys = [int(i) for i in doc_keys]
            mappings[int(key)] = doc_keys 
    return mappings

# %% [markdown]
# # Text Preprocessing:
# - The text is preprocessed to tokenise a document.
# - Temove stop words which are mostly commonly used in English text.
# - Convert numbers to it word representation.
# - Normalise text by lowercasing and string with only alphabets.
# - Stemming is performed to reduce the word to their root form.

# %%
class PreprocessText:
    def __init__(self, text):
        self.text = text
        
    def _tokenize(self):
        ''' 
        - tokenise the text using word_tokenize function.
        
        '''
        tokenizer = TreebankWordTokenizer()
        self.tokens = tokenizer.tokenize(self.text)  
        return self.tokens
    
    def _remove_stopwords(self):
        stop_words = set(stopwords.words('english'))
        return [word for word in self.tokens if word.lower() not in stop_words]
    
    def _convert_num_text(self):
        text_num = [num2words(word) if word.isnumeric() and word.isascii() else word for word in self.tokens]
        return text_num
    
    def _normalise_text(self):
        normalised_text = [word.lower() for word in self.tokens if word.isalpha()]
        return normalised_text  
    
    def _stem_text(self):
        stemmer = PorterStemmer()
        return [stemmer.stem(word) for word in self.tokens]
    
    def clean_text(self):
        self._tokenize()
        self.tokens = self._convert_num_text()
        self.tokens = self._normalise_text()
        self.tokens = self._remove_stopwords()
        self.tokens = self._stem_text()
        return self.tokens

# %% [markdown]
# # Inverted Index
# - Inverted index of the document is created as a dictionary where each preprocessed term key and the value is a key-value pair of document id and posting information of term frequency and IDF along with document frequency for the term.

# %%
@dataclass   
class Posting:
    freq: int = 1
    tfidf: float = 0.0
    
class InvertedIndexDocs:
    def __init__(self, documents):
        self._documents = self._clean_data(documents)
        self._indexdocs = dict()
        
    def _clean_data(self, document_list):
        clean_docs = {doc_id: PreprocessText(doc_text).clean_text() for doc_id, doc_text in document_list.items()}
        return clean_docs
    
    def create_index(self):
        self._index_docs()
        self._tfidf_docs()
        
    def _index_docs(self):
        for docid, docs in self._documents.items():
            for token in docs:
                if token not in self._indexdocs:
                    self._indexdocs[token] = InvertList()
                self._indexdocs[token].add_posting_doc(docid)
    
    def _tfidf_docs(self):
        for token, inv_index in self._indexdocs.items():
            for _, posting in inv_index.postings.items():
                term_freq = posting.freq
                idf = log(self.document_length / self._indexdocs[token].document_frequency)
                posting.tfidf = term_freq * idf
                
    @property
    def get_index(self):
        indexed_doc = {k:v for k,v in sorted(self._indexdocs.items())}
        return indexed_doc
    
    @property
    def documents_collection(self):
        return self._documents

    @property
    def words(self):
        return list(itertools.chain.from_iterable(self._documents.values()))

    @property
    def vocab(self):
        return sorted(self._indexdocs)

    @property
    def document_length(self):
        return len(self._documents)

    @property
    def word_count(self):
        return len(self.words)

    @property
    def vocab_count(self):
        return len(self._indexdocs)

    @property
    def avg_doc_length(self):
        return self.word_count / self.document_length

    @property
    def counter(self):
        return Counter(self.words)
    
class InvertList:
    def __init__(self):
        self._postings = dict()

    def add_posting_doc(self, docid):
        if self.contains_posting_data(docid):
            return self.update_posting(docid)
        posting = Posting()
        self._postings[docid] = posting

    def update_posting(self, docid):
        if not self.contains_posting_data(docid):
            return self.add_posting_doc(docid)
        posting = self._postings[docid]
        posting.freq += 1

    def get_posting(self, docid):
        return self._postings[docid]

    def contains_posting_data(self, docid):
        return docid in self._postings

    @property
    def postings(self):
        return self._postings

    @property
    def document_frequency(self):
        return len(self._postings)

# %% [markdown]
# # BM25 Model

# %%
class RunModel:
    def __init__(self, index, mapping):
        self._document_collection = index.documents_collection
        self._index = index.get_index
        self._mapping = mapping
        
    def rank(self, qid, query):
        query_words = self._clean_query_text(query)
        passages = self._relevant_docs(qid, query_words)

        scores = {}
        for docid in passages:
            scores[docid] = self._score_docs(docid, query_words)

        ranking = sorted(scores.items(), key=lambda item: item[1], reverse=True)
        ranks = {docid: score for docid, score in ranking}
        return ranks

    def _clean_query_text(self, query):
        clean_query_text = [word for word in PreprocessText(query).clean_text()]
        return clean_query_text

    def _relevant_docs(self, qid, query_words):
        relevant_docs_set = set()
        for word in query_words:
            if word in self._index:
                for docid in self._index[word].postings:
                    if docid in self._mapping[qid]:
                        relevant_docs_set.add(docid)
        return list(relevant_docs_set)

class BM25(RunModel):
    def __init__(self, index, mapping):
        super().__init__(index, mapping)
        self._doc_length = index.document_length
        self._avg_length = index.avg_doc_length

    def _score_docs(self, docid: int, query_words) -> float:
        BM25_score = 0
        for word in query_words:
            if word not in self._index or not self._index[word].contains_posting_data(docid):
                continue
            BM25_score += self._score(docid, word)
        return BM25_score

    def _score(self, docid: int, word: str) -> float:
        # Constants
        k1 = 1.2
        b = 0.75

        # Parameters
        inv_index = self._index[word]
        doc_length = self._doc_length
        doc_freq = inv_index.document_frequency
        tf = inv_index.get_posting(docid).freq
        dl = float(len(self._document_collection[docid])) 
        avg_doc_length = float(self._avg_length)

        # Formulas
        K = k1 * ((1 - b) + b * (dl / avg_doc_length))
        first_exp = log(((doc_length - doc_freq + 0.5) / (doc_freq + 0.5)) + 1)
        second_exp = ((tf * (k1 + 1)) / (tf + K))
        return first_exp * second_exp

# %% [markdown]
# # VSM

# %%
class VSM(RunModel):
    def __init__(self, index, mapping):
        super().__init__(index, mapping)
        self._vocab = index.vocab
        self._collection_length = index.document_length
        self._vocab_count = index.vocab_count

    def _score_docs(self, docid: int, query_words) -> float:
        vocab = list(set(self._document_collection[docid]))
        vocab_count = len(vocab)

        doc_vector = np.zeros(vocab_count)
        for i, word in enumerate(vocab):
            doc_vector[i] = self._index[word].get_posting(docid).tfidf

        query_vector = np.zeros(vocab_count)
        counter = Counter(query_words)
        max_freq = counter.most_common(1)[0][1]
        for word in query_words:
            if word not in self._index:
                continue
            tf = (0.5 + (0.5 * (counter[word] / max_freq)))
            idf = log(self._collection_length / self._index[word].document_frequency)
            tfidf = tf * idf
            if word in vocab:
                wordidx = vocab.index(word)
                query_vector[wordidx] = tfidf
            else:
                query_vector = np.append(query_vector, tfidf)
                doc_vector = np.append(doc_vector, 0)
                
        cosine_similarity = np.dot(doc_vector, query_vector) / (np.linalg.norm(doc_vector) * np.linalg.norm(query_vector))
        return cosine_similarity

# %% [markdown]
# # Query likelihood model with Laplace Smoothing

# %%
class LanguageModel(RunModel):
    def __init__(self, index, mapping):
        super().__init__(index, mapping)
        self._all_words = index.words
        self._word_count = index.word_count
        self._vocab_count = index.vocab_count
        self._counter = index.counter
        
    def _score_docs(self, docid: int, query_words) -> float:
        prob = []
        for token in query_words:
            prob.append(self._calc_probability(docid, token))
        try:
            return log(np.prod(prob))
        except ValueError:
            return 0.0
    
    def _calc_probability(self, docid: int, token: str) -> float:
        term_freq = self._index[token].get_posting(docid).freq if token in self._document_collection[docid] else 0
        document_length = len(self._document_collection[docid])
        vocab = self._vocab_count
        probability = (term_freq + 1) / (document_length + vocab)
        return probability

# %%
input_docs = r'./data/cran.all.1400.xml'

read_documents = ReadDocs(input_docs)
read_documents.load_split_docs()
cran_docs = read_documents.read_document()

query_path = r'./data/cran.qry.xml'
read_query = ReadQueries(query_path)
read_query.load_split_query()
cran_queries = read_query.index_queries()

def generate_index(doc_collection):
    index = InvertedIndexDocs(doc_collection)
    index.create_index()
    return index

inv_index = generate_index(cran_docs)

for k, v in inv_index.get_index.items():
    print(f'the term is {k}, posting list is {v.postings} and document frequency is {v.document_frequency}')
# Out:
# the term is ab, posting list is {744: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is abbrevi, posting list is {122: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is abil, posting list is {51: Posting(freq=1, tfidf=6.144185634125646), 77: Posting(freq=1, tfidf=6.144185634125646), 738: Posting(freq=1, tfidf=6.144185634125646)} and document frequency is 3
# the term is abl, posting list is {99: Posting(freq=1, tfidf=4.94021282979971), 132: Posting(freq=1, tfidf=4.94021282979971), 536: Posting(freq=1, tfidf=4.94021282979971), 581: Posting(freq=1, tfidf=4.94021282979971), 695: Posting(freq=1, tfidf=4.94021282979971), 763: Posting(freq=1, tfidf=4.94021282979971), 908: Posting(freq=1, tfidf=4.94021282979971), 914: Posting(freq=1, tfidf=4.94021282979971), 986: Posting(freq=1, tfidf=4.94021282979971), 1114: Posting(freq=1, tfidf=4.94021282979971)} and document frequency is 10
# the term is ablat, posting list is {82: Posting(freq=2, tfidf=9.207481186356993), 274: Posting(freq=2, tfidf=9.207481186356993), 553: Posting(freq=7, tfidf=32.22618415224947), 587: Posting(freq=1, tfidf=4.603740593178497), 1065: Posting(freq=2, tfidf=9.207481186356993), 1096: Posting(freq=2, tfidf=9.207481186356993), 1097: Posting(freq=7, tfidf=32.22618415224947), 1098: Posting(freq=3, tfidf=13.81122177953549), 1099: Posting(freq=4, tfidf=18.414962372713987), 1100: Posting(freq=4, tfidf=18.414962372713987), 1101: Posting(freq=2, tfidf=9.207481186356993), 1226: Posting(freq=3, tfidf=13.81122177953549), 1241: Posting(freq=3, tfidf=13.81122177953549), 1279: Posting(freq=1, tfidf=4.603740593178497)} and document frequency is 14
# the term is abrupt, posting list is {1039: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is abruptli, posting list is {439: Posting(freq=1, tfidf=6.144185634125646), 662: Posting(freq=1, tfidf=6.144185634125646), 992: Posting(freq=1, tfidf=6.144185634125646)} and document frequency is 3
# the term is absenc, posting list is {152: Posting(freq=1, tfidf=5.045573345457536), 499: Posting(freq=2, tfidf=10.091146690915073), 757: Posting(freq=1, tfidf=5.045573345457536), 966: Posting(freq=1, tfidf=5.045573345457536), 1147: Posting(freq=1, tfidf=5.045573345457536), 1237: Posting(freq=1, tfidf=5.045573345457536), 1281: Posting(freq=1, tfidf=5.045573345457536), 1321: Posting(freq=1, tfidf=5.045573345457536), 1323: Posting(freq=1, tfidf=5.045573345457536)} and document frequency is 9
# the term is absent, posting list is {628: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is absolut, posting list is {62: Posting(freq=2, tfidf=9.68980529999077), 414: Posting(freq=1, tfidf=4.844902649995385), 460: Posting(freq=1, tfidf=4.844902649995385), 474: Posting(freq=1, tfidf=4.844902649995385), 562: Posting(freq=1, tfidf=4.844902649995385), 987: Posting(freq=1, tfidf=4.844902649995385), 1003: Posting(freq=2, tfidf=9.68980529999077), 1010: Posting(freq=1, tfidf=4.844902649995385), 1035: Posting(freq=1, tfidf=4.844902649995385), 1261: Posting(freq=1, tfidf=4.844902649995385), 1395: Posting(freq=1, tfidf=4.844902649995385)} and document frequency is 11
# the term is absorb, posting list is {163: Posting(freq=1, tfidf=5.163356381113919), 164: Posting(freq=1, tfidf=5.163356381113919), 353: Posting(freq=1, tfidf=5.163356381113919), 373: Posting(freq=1, tfidf=5.163356381113919), 881: Posting(freq=1, tfidf=5.163356381113919), 1147: Posting(freq=1, tfidf=5.163356381113919), 1200: Posting(freq=1, tfidf=5.163356381113919), 1279: Posting(freq=1, tfidf=5.163356381113919)} and document frequency is 8
# the term is absorpt, posting list is {166: Posting(freq=1, tfidf=5.633360010359655), 357: Posting(freq=2, tfidf=11.26672002071931), 620: Posting(freq=2, tfidf=11.26672002071931), 1316: Posting(freq=1, tfidf=5.633360010359655), 1346: Posting(freq=1, tfidf=5.633360010359655)} and document frequency is 5
# the term is abstract, posting list is {154: Posting(freq=1, tfidf=6.54965074223381), 479: Posting(freq=1, tfidf=6.54965074223381)} and document frequency is 2
# the term is abundantli, posting list is {718: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is academ, posting list is {344: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is acceler, posting list is {29: Posting(freq=1, tfidf=3.9105934126185518), 33: Posting(freq=1, tfidf=3.9105934126185518), 34: Posting(freq=3, tfidf=11.731780237855656), 51: Posting(freq=2, tfidf=7.8211868252371035), 83: Posting(freq=1, tfidf=3.9105934126185518), 164: Posting(freq=3, tfidf=11.731780237855656), 208: Posting(freq=1, tfidf=3.9105934126185518), 290: Posting(freq=2, tfidf=7.8211868252371035), 292: Posting(freq=1, tfidf=3.9105934126185518), 330: Posting(freq=1, tfidf=3.9105934126185518), 339: Posting(freq=1, tfidf=3.9105934126185518), 459: Posting(freq=1, tfidf=3.9105934126185518), 562: Posting(freq=1, tfidf=3.9105934126185518), 595: Posting(freq=1, tfidf=3.9105934126185518), 620: Posting(freq=1, tfidf=3.9105934126185518), 662: Posting(freq=1, tfidf=3.9105934126185518), 698: Posting(freq=1, tfidf=3.9105934126185518), 768: Posting(freq=1, tfidf=3.9105934126185518), 788: Posting(freq=1, tfidf=3.9105934126185518), 813: Posting(freq=1, tfidf=3.9105934126185518), 814: Posting(freq=1, tfidf=3.9105934126185518), 832: Posting(freq=2, tfidf=7.8211868252371035), 896: Posting(freq=1, tfidf=3.9105934126185518), 967: Posting(freq=4, tfidf=15.642373650474207), 1201: Posting(freq=1, tfidf=3.9105934126185518), 1219: Posting(freq=3, tfidf=11.731780237855656), 1242: Posting(freq=1, tfidf=3.9105934126185518), 1346: Posting(freq=1, tfidf=3.9105934126185518)} and document frequency is 28
# the term is acceleromet, posting list is {882: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is accentu, posting list is {1169: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is accept, posting list is {101: Posting(freq=1, tfidf=4.470209200553974), 253: Posting(freq=1, tfidf=4.470209200553974), 388: Posting(freq=1, tfidf=4.470209200553974), 575: Posting(freq=1, tfidf=4.470209200553974), 656: Posting(freq=1, tfidf=4.470209200553974), 753: Posting(freq=1, tfidf=4.470209200553974), 819: Posting(freq=1, tfidf=4.470209200553974), 841: Posting(freq=1, tfidf=4.470209200553974), 1002: Posting(freq=1, tfidf=4.470209200553974), 1019: Posting(freq=1, tfidf=4.470209200553974), 1153: Posting(freq=1, tfidf=4.470209200553974), 1242: Posting(freq=1, tfidf=4.470209200553974), 1261: Posting(freq=1, tfidf=4.470209200553974), 1346: Posting(freq=1, tfidf=4.470209200553974), 1347: Posting(freq=1, tfidf=4.470209200553974), 1370: Posting(freq=1, tfidf=4.470209200553974)} and document frequency is 16
# the term is access, posting list is {1105: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is accident, posting list is {715: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is accommod, posting list is {168: Posting(freq=1, tfidf=5.4510384535657), 518: Posting(freq=3, tfidf=16.3531153606971), 974: Posting(freq=1, tfidf=5.4510384535657), 1056: Posting(freq=1, tfidf=5.4510384535657), 1147: Posting(freq=2, tfidf=10.9020769071314), 1239: Posting(freq=1, tfidf=5.4510384535657)} and document frequency is 6
# the term is accompani, posting list is {53: Posting(freq=1, tfidf=4.677848565332218), 109: Posting(freq=1, tfidf=4.677848565332218), 152: Posting(freq=1, tfidf=4.677848565332218), 207: Posting(freq=1, tfidf=4.677848565332218), 261: Posting(freq=1, tfidf=4.677848565332218), 296: Posting(freq=1, tfidf=4.677848565332218), 520: Posting(freq=1, tfidf=4.677848565332218), 589: Posting(freq=1, tfidf=4.677848565332218), 638: Posting(freq=1, tfidf=4.677848565332218), 724: Posting(freq=1, tfidf=4.677848565332218), 797: Posting(freq=1, tfidf=4.677848565332218), 1147: Posting(freq=1, tfidf=4.677848565332218), 1277: Posting(freq=1, tfidf=4.677848565332218)} and document frequency is 13
# the term is accomplish, posting list is {47: Posting(freq=1, tfidf=4.844902649995385), 163: Posting(freq=1, tfidf=4.844902649995385), 172: Posting(freq=1, tfidf=4.844902649995385), 192: Posting(freq=1, tfidf=4.844902649995385), 355: Posting(freq=1, tfidf=4.844902649995385), 363: Posting(freq=1, tfidf=4.844902649995385), 579: Posting(freq=1, tfidf=4.844902649995385), 718: Posting(freq=1, tfidf=4.844902649995385), 727: Posting(freq=1, tfidf=4.844902649995385), 968: Posting(freq=1, tfidf=4.844902649995385), 1147: Posting(freq=2, tfidf=9.68980529999077)} and document frequency is 11
# the term is accord, posting list is {110: Posting(freq=1, tfidf=3.631880010149531), 125: Posting(freq=1, tfidf=3.631880010149531), 133: Posting(freq=1, tfidf=3.631880010149531), 134: Posting(freq=1, tfidf=3.631880010149531), 152: Posting(freq=1, tfidf=3.631880010149531), 263: Posting(freq=2, tfidf=7.263760020299062), 297: Posting(freq=1, tfidf=3.631880010149531), 317: Posting(freq=1, tfidf=3.631880010149531), 377: Posting(freq=1, tfidf=3.631880010149531), 403: Posting(freq=1, tfidf=3.631880010149531), 410: Posting(freq=1, tfidf=3.631880010149531), 455: Posting(freq=1, tfidf=3.631880010149531), 542: Posting(freq=1, tfidf=3.631880010149531), 573: Posting(freq=1, tfidf=3.631880010149531), 585: Posting(freq=1, tfidf=3.631880010149531), 614: Posting(freq=1, tfidf=3.631880010149531), 667: Posting(freq=1, tfidf=3.631880010149531), 818: Posting(freq=1, tfidf=3.631880010149531), 827: Posting(freq=1, tfidf=3.631880010149531), 874: Posting(freq=1, tfidf=3.631880010149531), 883: Posting(freq=1, tfidf=3.631880010149531), 899: Posting(freq=1, tfidf=3.631880010149531), 927: Posting(freq=1, tfidf=3.631880010149531), 934: Posting(freq=1, tfidf=3.631880010149531), 1014: Posting(freq=1, tfidf=3.631880010149531), 1035: Posting(freq=1, tfidf=3.631880010149531), 1036: Posting(freq=1, tfidf=3.631880010149531), 1061: Posting(freq=1, tfidf=3.631880010149531), 1072: Posting(freq=1, tfidf=3.631880010149531), 1075: Posting(freq=1, tfidf=3.631880010149531), 1127: Posting(freq=2, tfidf=7.263760020299062), 1136: Posting(freq=1, tfidf=3.631880010149531), 1186: Posting(freq=2, tfidf=7.263760020299062), 1199: Posting(freq=1, tfidf=3.631880010149531), 1244: Posting(freq=1, tfidf=3.631880010149531), 1304: Posting(freq=2, tfidf=7.263760020299062), 1375: Posting(freq=1, tfidf=3.631880010149531)} and document frequency is 37
# the term is accordingli, posting list is {179: Posting(freq=1, tfidf=5.163356381113919), 184: Posting(freq=1, tfidf=5.163356381113919), 188: Posting(freq=1, tfidf=5.163356381113919), 458: Posting(freq=1, tfidf=5.163356381113919), 625: Posting(freq=1, tfidf=5.163356381113919), 718: Posting(freq=1, tfidf=5.163356381113919), 1072: Posting(freq=1, tfidf=5.163356381113919), 1373: Posting(freq=1, tfidf=5.163356381113919)} and document frequency is 8
# the term is account, posting list is {22: Posting(freq=1, tfidf=2.836078675529502), 25: Posting(freq=1, tfidf=2.836078675529502), 26: Posting(freq=1, tfidf=2.836078675529502), 42: Posting(freq=1, tfidf=2.836078675529502), 44: Posting(freq=1, tfidf=2.836078675529502), 52: Posting(freq=1, tfidf=2.836078675529502), 63: Posting(freq=1, tfidf=2.836078675529502), 72: Posting(freq=1, tfidf=2.836078675529502), 78: Posting(freq=1, tfidf=2.836078675529502), 87: Posting(freq=1, tfidf=2.836078675529502), 97: Posting(freq=1, tfidf=2.836078675529502), 132: Posting(freq=2, tfidf=5.672157351059004), 134: Posting(freq=1, tfidf=2.836078675529502), 149: Posting(freq=1, tfidf=2.836078675529502), 170: Posting(freq=1, tfidf=2.836078675529502), 171: Posting(freq=1, tfidf=2.836078675529502),
.687449861304342), 733: Posting(freq=1, tfidf=3.687449861304342), 792: Posting(freq=2, tfidf=7.374899722608684), 820: Posting(freq=1, tfidf=3.687449861304342), 838: Posting(freq=1, tfidf=3.687449861304342), 869: Posting(freq=1, tfidf=3.687449861304342), 1051: Posting(freq=1, tfidf=3.687449861304342), 1089: Posting(freq=1, tfidf=3.687449861304342), 1095: Posting(freq=1, tfidf=3.687449861304342), 1143: Posting(freq=2, tfidf=7.374899722608684), 1205: Posting(freq=1, tfidf=3.687449861304342), 1207: Posting(freq=1, tfidf=3.687449861304342), 1246: Posting(freq=1, tfidf=3.687449861304342), 1263: Posting(freq=1, tfidf=3.687449861304342), 1264: Posting(freq=1, tfidf=3.687449861304342), 1268: Posting(freq=1, tfidf=3.687449861304342), 1323: Posting(freq=1, tfidf=3.687449861304342), 1347: Posting(freq=1, tfidf=3.687449861304342)} and document frequency is 35
# the term is ackeret, posting list is {14: Posting(freq=1, tfidf=5.856503561673865), 297: Posting(freq=1, tfidf=5.856503561673865), 390: Posting(freq=1, tfidf=5.856503561673865), 1249: Posting(freq=1, tfidf=5.856503561673865)} and document frequency is 4
# the term is acoust, posting list is {65: Posting(freq=1, tfidf=4.534747721691546), 75: Posting(freq=3, tfidf=13.604243165074639), 113: Posting(freq=1, tfidf=4.534747721691546), 151: Posting(freq=4, tfidf=18.138990886766184), 209: Posting(freq=1, tfidf=4.534747721691546), 640: Posting(freq=1, tfidf=4.534747721691546), 720: Posting(freq=3, tfidf=13.604243165074639), 721: Posting(freq=2, tfidf=9.069495443383092), 722: Posting(freq=1, tfidf=4.534747721691546), 724: Posting(freq=7, tfidf=31.743234051840822), 727: Posting(freq=1, tfidf=4.534747721691546), 899: Posting(freq=1, tfidf=4.534747721691546), 1208: Posting(freq=3, tfidf=13.604243165074639), 1244: Posting(freq=12, tfidf=54.416972660298555), 1276: Posting(freq=1, tfidf=4.534747721691546)} and document frequency is 15
# the term is acquir, posting list is {523: Posting(freq=1, tfidf=6.54965074223381), 1255: Posting(freq=1, tfidf=6.54965074223381)} and document frequency is 2
# the term is acquisit, posting list is {701: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is acr, posting list is {216: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is acrodynam, posting list is {1207: Posting(freq=2, tfidf=14.485595845587511)} and document frequency is 1
# the term is across, posting list is {15: Posting(freq=1, tfidf=3.436135433023436), 45: Posting(freq=1, tfidf=3.436135433023436), 50: Posting(freq=1, tfidf=3.436135433023436), 62: Posting(freq=1, tfidf=3.436135433023436), 82: Posting(freq=1, tfidf=3.436135433023436), 89: Posting(freq=1, tfidf=3.436135433023436), 101: Posting(freq=2, tfidf=6.872270866046872), 109: Posting(freq=1, tfidf=3.436135433023436), 110: Posting(freq=1, tfidf=3.436135433023436), 128: Posting(freq=1, tfidf=3.436135433023436), 177: Posting(freq=1, tfidf=3.436135433023436), 190: Posting(freq=1, tfidf=3.436135433023436), 212: Posting(freq=1, tfidf=3.436135433023436), 213: Posting(freq=1, tfidf=3.436135433023436), 216: Posting(freq=1, tfidf=3.436135433023436), 230: Posting(freq=1, tfidf=3.436135433023436), 257: Posting(freq=1, tfidf=3.436135433023436), 277: Posting(freq=1, tfidf=3.436135433023436), 349: Posting(freq=1, tfidf=3.436135433023436), 374: Posting(freq=1, tfidf=3.436135433023436), 459: Posting(freq=1, tfidf=3.436135433023436), 565: Posting(freq=1, tfidf=3.436135433023436), 576: Posting(freq=1, tfidf=3.436135433023436), 603: Posting(freq=1, tfidf=3.436135433023436), 606: Posting(freq=1, tfidf=3.436135433023436), 667: Posting(freq=1, tfidf=3.436135433023436), 727: Posting(freq=1, tfidf=3.436135433023436), 737: Posting(freq=1, tfidf=3.436135433023436), 805: Posting(freq=1, tfidf=3.436135433023436), 808: Posting(freq=1, tfidf=3.436135433023436), 949: Posting(freq=1, tfidf=3.436135433023436), 960: Posting(freq=1, tfidf=3.436135433023436), 962: Posting(freq=1, tfidf=3.436135433023436), 966: Posting(freq=1, tfidf=3.436135433023436), 975: Posting(freq=1, tfidf=3.436135433023436), 990: Posting(freq=1, tfidf=3.436135433023436), 1127: Posting(freq=1, tfidf=3.436135433023436), 1198: Posting(freq=1, tfidf=3.436135433023436), 1202: Posting(freq=1, tfidf=3.436135433023436), 1226: Posting(freq=1, tfidf=3.436135433023436), 1239: Posting(freq=1, tfidf=3.436135433023436), 1244: Posting(freq=2, tfidf=6.872270866046872), 1269: Posting(freq=1, tfidf=3.436135433023436), 1277: Posting(freq=1, tfidf=3.436135433023436), 1289: Posting(freq=1, tfidf=3.436135433023436)} and document frequency is 45
# the term is acrothermochemistri, posting list is {1254: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is acrothermoelast, posting list is {12: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is act, posting list is {44: Posting(freq=1, tfidf=4.1517554694354395), 51: Posting(freq=2, tfidf=8.303510938870879), 52: Posting(freq=1, tfidf=4.1517554694354395), 87: Posting(freq=1, tfidf=4.1517554694354395), 104: Posting(freq=1, tfidf=4.1517554694354395), 174: Posting(freq=1, tfidf=4.1517554694354395), 202: Posting(freq=1, tfidf=4.1517554694354395), 210: Posting(freq=1, tfidf=4.1517554694354395), 267: Posting(freq=1, tfidf=4.1517554694354395), 427: Posting(freq=1, tfidf=4.1517554694354395), 506: Posting(freq=1, tfidf=4.1517554694354395), 509: Posting(freq=1, tfidf=4.1517554694354395), 582: Posting(freq=1, tfidf=4.1517554694354395), 894: Posting(freq=2, tfidf=8.303510938870879), 895: Posting(freq=1, tfidf=4.1517554694354395), 899: Posting(freq=1, tfidf=4.1517554694354395), 1005: Posting(freq=1, tfidf=4.1517554694354395), 1059: Posting(freq=1, tfidf=4.1517554694354395), 1256: Posting(freq=2, tfidf=8.303510938870879), 1304: Posting(freq=1, tfidf=4.1517554694354395), 1329: Posting(freq=1, tfidf=4.1517554694354395), 1333: Posting(freq=2, tfidf=8.303510938870879)} and document frequency is 22
# the term is action, posting list is {100: Posting(freq=1, tfidf=4.94021282979971), 170: Posting(freq=1, tfidf=4.94021282979971), 211: Posting(freq=1, tfidf=4.94021282979971), 424: Posting(freq=1, tfidf=4.94021282979971), 821: Posting(freq=1, tfidf=4.94021282979971), 860: Posting(freq=1, tfidf=4.94021282979971), 934: Posting(freq=3, tfidf=14.82063848939913), 992: Posting(freq=1, tfidf=4.94021282979971), 1244: Posting(freq=5, tfidf=24.701064148998547), 1255: Posting(freq=1, tfidf=4.94021282979971)} and document frequency is 10
# the term is activ, posting list is {83: Posting(freq=2, tfidf=9.515782546011511), 185: Posting(freq=1, tfidf=4.757891273005756), 518: Posting(freq=2, tfidf=9.515782546011511), 622: Posting(freq=1, tfidf=4.757891273005756), 871: Posting(freq=1, tfidf=4.757891273005756), 908: Posting(freq=1, tfidf=4.757891273005756), 1061: Posting(freq=1, tfidf=4.757891273005756), 1103: Posting(freq=1, tfidf=4.757891273005756), 1131: Posting(freq=2, tfidf=9.515782546011511), 1241: Posting(freq=1, tfidf=4.757891273005756), 1268: Posting(freq=1, tfidf=4.757891273005756), 1284: Posting(freq=1, tfidf=4.757891273005756)} and document frequency is 12
# the term is actual, posting list is {44: Posting(freq=1, tfidf=3.5292258560894476), 73: Posting(freq=1, tfidf=3.5292258560894476), 80: Posting(freq=1, tfidf=3.5292258560894476), 97: Posting(freq=1, tfidf=3.5292258560894476), 123: Posting(freq=1, tfidf=3.5292258560894476), 198: Posting(freq=1, tfidf=3.5292258560894476), 201: Posting(freq=1, tfidf=3.5292258560894476), 210: Posting(freq=1, tfidf=3.5292258560894476), 211: Posting(freq=1, tfidf=3.5292258560894476), 236: Posting(freq=1, tfidf=3.5292258560894476), 283: Posting(freq=1, tfidf=3.5292258560894476), 292: Posting(freq=1, tfidf=3.5292258560894476), 304: Posting(freq=1, tfidf=3.5292258560894476), 363: Posting(freq=1, tfidf=3.5292258560894476), 435: Posting(freq=1, tfidf=3.5292258560894476), 443: Posting(freq=1, tfidf=3.5292258560894476), 453: Posting(freq=1, tfidf=3.5292258560894476), 459: Posting(freq=2, tfidf=7.058451712178895), 500: Posting(freq=1, tfidf=3.5292258560894476), 618: Posting(freq=1, tfidf=3.5292258560894476), 671: Posting(freq=1, tfidf=3.5292258560894476), 695: Posting(freq=1, tfidf=3.5292258560894476), 729: Posting(freq=1, tfidf=3.5292258560894476), 739: Posting(freq=1, tfidf=3.5292258560894476), 826: Posting(freq=1, tfidf=3.5292258560894476), 829: Posting(freq=1, tfidf=3.5292258560894476), 847: Posting(freq=1, tfidf=3.5292258560894476), 928: Posting(freq=1, tfidf=3.5292258560894476), 1016: Posting(freq=1, tfidf=3.5292258560894476), 1071: Posting(freq=1, tfidf=3.5292258560894476), 1127: Posting(freq=1, tfidf=3.5292258560894476), 1133: Posting(freq=1, tfidf=3.5292258560894476), 1134: Posting(freq=1, tfidf=3.5292258560894476), 1195: Posting(freq=2, tfidf=7.058451712178895), 1198: Posting(freq=1, tfidf=3.5292258560894476), 1225: Posting(freq=1, tfidf=3.5292258560894476), 1275: Posting(freq=1, tfidf=3.5292258560894476), 1342: Posting(freq=1, tfidf=3.5292258560894476), 1361: Posting(freq=1, tfidf=3.5292258560894476), 1382: Posting(freq=1, tfidf=3.5292258560894476), 1394: Posting(freq=1, tfidf=3.5292258560894476)} and document frequency is 41
# the term is actur, posting list is {201: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term
# the term is adequ, posting list is {54: Posting(freq=1, tfidf=4.247065649239764), 89: Posting(freq=1, tfidf=4.247065649239764), 92: Posting(freq=1, tfidf=4.247065649239764), 93: Posting(freq=1, tfidf=4.247065649239764), 171: Posting(freq=1, tfidf=4.247065649239764), 179: Posting(freq=1, tfidf=4.247065649239764), 184: Posting(freq=1, tfidf=4.247065649239764), 196: Posting(freq=1, tfidf=4.247065649239764), 210: Posting(freq=1, tfidf=4.247065649239764), 225: Posting(freq=1, tfidf=4.247065649239764), 441: Posting(freq=1, tfidf=4.247065649239764), 557: Posting(freq=1, tfidf=4.247065649239764), 567: Posting(freq=1, tfidf=4.247065649239764), 603: Posting(freq=2, tfidf=8.494131298479529), 618: Posting(freq=1, tfidf=4.247065649239764), 729: Posting(freq=1, tfidf=4.247065649239764), 801: Posting(freq=1, tfidf=4.247065649239764), 927: Posting(freq=1, tfidf=4.247065649239764), 1039: Posting(freq=1, tfidf=4.247065649239764), 1136: Posting(freq=1, tfidf=4.247065649239764)} and document frequency is 20
# the term is adequaci, posting list is {459: Posting(freq=1, tfidf=6.54965074223381), 652: Posting(freq=1, tfidf=6.54965074223381)} and document frequency is 2
# the term is adiabat, posting list is {53: Posting(freq=1, tfidf=4.247065649239764), 54: Posting(freq=1, tfidf=4.247065649239764), 80: Posting(freq=1, tfidf=4.247065649239764), 84: Posting(freq=1, tfidf=4.247065649239764), 90: Posting(freq=1, tfidf=4.247065649239764), 217: Posting(freq=1, tfidf=4.247065649239764), 340: Posting(freq=1, tfidf=4.247065649239764), 413: Posting(freq=1, tfidf=4.247065649239764), 426: Posting(freq=1, tfidf=4.247065649239764), 480: Posting(freq=1, tfidf=4.247065649239764), 505: Posting(freq=2, tfidf=8.494131298479529), 623: Posting(freq=1, tfidf=4.247065649239764), 645: Posting(freq=1, tfidf=4.247065649239764), 646: Posting(freq=2, tfidf=8.494131298479529), 941: Posting(freq=1, tfidf=4.247065649239764), 986: Posting(freq=1, tfidf=4.247065649239764), 1105: Posting(freq=2, tfidf=8.494131298479529), 1180: Posting(freq=1, tfidf=4.247065649239764), 1327: Posting(freq=1, tfidf=4.247065649239764), 1335: Posting(freq=1, tfidf=4.247065649239764)} and document frequency is 20
# the term is adjac, posting list is {100: Posting(freq=1, tfidf=4.107303706864606), 121: Posting(freq=1, tfidf=4.107303706864606), 134: Posting(freq=1, tfidf=4.107303706864606), 168: Posting(freq=1, tfidf=4.107303706864606), 211: Posting(freq=1, tfidf=4.107303706864606), 219: Posting(freq=1, tfidf=4.107303706864606), 282: Posting(freq=1, tfidf=4.107303706864606), 341: Posting(freq=1, tfidf=4.107303706864606), 422: Posting(freq=1, tfidf=4.107303706864606), 434: Posting(freq=1, tfidf=4.107303706864606), 576: Posting(freq=1, tfidf=4.107303706864606), 588: Posting(freq=1, tfidf=4.107303706864606), 589: Posting(freq=1, tfidf=4.107303706864606), 644: Posting(freq=1, tfidf=4.107303706864606), 647: Posting(freq=2, tfidf=8.214607413729212), 695: Posting(freq=1, tfidf=4.107303706864606), 697: Posting(freq=2, tfidf=8.214607413729212), 869: Posting(freq=1, tfidf=4.107303706864606), 971: Posting(freq=1, tfidf=4.107303706864606), 989: Posting(freq=1, tfidf=4.107303706864606), 1144: Posting(freq=1, tfidf=4.107303706864606), 1202: Posting(freq=2, tfidf=8.214607413729212), 1288: Posting(freq=1, tfidf=4.107303706864606)} and document frequency is 23
# the term is adjoin, posting list is {665: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is adjoint, posting list is {379: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is adjust, posting list is {178: Posting(freq=1, tfidf=4.844902649995385), 204: Posting(freq=1, tfidf=4.844902649995385), 358: Posting(freq=1, tfidf=4.844902649995385), 366: Posting(freq=1, tfidf=4.844902649995385), 426: Posting(freq=1, tfidf=4.844902649995385), 458: Posting(freq=1, tfidf=4.844902649995385), 576: Posting(freq=1, tfidf=4.844902649995385), 588: Posting(freq=1, tfidf=4.844902649995385), 1195: Posting(freq=1, tfidf=4.844902649995385), 1202: Posting(freq=2, tfidf=9.68980529999077), 1257: Posting(freq=1, tfidf=4.844902649995385)} and document frequency is 11
# the term is administr, posting list is {1065: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is admiss, posting list is {1128: Posting(freq=1, tfidf=6.54965074223381), 1373: Posting(freq=1, tfidf=6.54965074223381)} and document frequency is 2
# the term is admit, posting list is {62: Posting(freq=1, tfidf=5.633360010359655), 191: Posting(freq=1, tfidf=5.633360010359655), 730: Posting(freq=1, tfidf=5.633360010359655), 1184: Posting(freq=2, tfidf=11.26672002071931), 1372: Posting(freq=1, tfidf=5.633360010359655)} and document frequency is 5
# the term is admixtur, posting list is {481: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is adopt, posting list is {107: Posting(freq=1, tfidf=5.296887773738442), 149: Posting(freq=1, tfidf=5.296887773738442), 640: Posting(freq=1, tfidf=5.296887773738442), 704: Posting(freq=1, tfidf=5.296887773738442), 733: Posting(freq=1, tfidf=5.296887773738442), 734: Posting(freq=1, tfidf=5.296887773738442), 1108: Posting(freq=1, tfidf=5.296887773738442)} and document frequency is 7
# the term is adsorpt, posting list is {585: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is advanc, posting list is {71: Posting(freq=2, tfidf=8.704852329795182), 72: Posting(freq=1, tfidf=4.352426164897591), 132: Posting(freq=1, tfidf=4.352426164897591), 187: Posting(freq=1, tfidf=4.352426164897591), 315: Posting(freq=1, tfidf=4.352426164897591), 406: Posting(freq=1, tfidf=4.352426164897591), 486: Posting(freq=1, tfidf=4.352426164897591), 521: Posting(freq=1, tfidf=4.352426164897591), 718: Posting(freq=1, tfidf=4.352426164897591), 739: Posting(freq=1, tfidf=4.352426164897591), 892: Posting(freq=1, tfidf=4.352426164897591), 933: Posting(freq=1, tfidf=4.352426164897591), 1052: Posting(freq=1, tfidf=4.352426164897591), 1160: Posting(freq=1, tfidf=4.352426164897591), 1244: Posting(freq=1, tfidf=4.352426164897591), 1294: Posting(freq=1, tfidf=4.352426164897591), 1295: Posting(freq=3, tfidf=13.057278494692774), 1362: Posting(freq=1, tfidf=4.352426164897591)} and document frequency is 18
# the term is advantag, posting list is {33: Posting(freq=1, tfidf=4.0239220979255546), 34: Posting(freq=1, tfidf=4.0239220979255546), 77: Posting(freq=1, tfidf=4.0239220979255546), 102: Posting(freq=1, tfidf=4.0239220979255546), 185: Posting(freq=2, tfidf=8.047844195851109), 206: Posting(freq=1, tfidf=4.0239220979255546), 225: Posting(freq=1, tfidf=4.0239220979255546), 244: Posting(freq=1, tfidf=4.0239220979255546), 253: Posting(freq=1, tfidf=4.0239220979255546), 477: Posting(freq=1, tfidf=4.0239220979255546), 611: Posting(freq=1, tfidf=4.0239220979255546), 747: Posting(freq=1, tfidf=4.0239220979255546), 869: Posting(freq=1, tfidf=4.0239220979255546), 876: Posting(freq=1, tfidf=4.0239220979255546), 889: Posting(freq=1, tfidf=4.0239220979255546), 962: Posting(freq=1, tfidf=4.0239220979255546), 1044: Posting(freq=1, tfidf=4.0239220979255546), 1054: Posting(freq=1, tfidf=4.0239220979255546), 1086: Posting(freq=1, tfidf=4.0239220979255546), 1137: Posting(freq=1, tfidf=4.0239220979255546), 1147: Posting(freq=1, tfidf=4.0239220979255546), 1239: Posting(freq=2, tfidf=8.047844195851109), 1289: Posting(freq=1, tfidf=4.0239220979255546), 1313: Posting(freq=1, tfidf=4.0239220979255546), 1388: Posting(freq=1, tfidf=4.0239220979255546)} and document frequency is 25
# the term is advent, posting list is {293: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is advers, posting list is {40: Posting(freq=1, tfidf=4.107303706864606), 54: Posting(freq=1, tfidf=4.107303706864606), 55: Posting(freq=1, tfidf=4.107303706864606), 62: Posting(freq=1, tfidf=4.107303706864606), 79: Posting(freq=1, tfidf=4.107303706864606), 145: Posting(freq=1, tfidf=4.107303706864606), 466: Posting(freq=1, tfidf=4.107303706864606), 481: Posting(freq=1, tfidf=4.107303706864606), 489: Posting(freq=1, tfidf=4.107303706864606), 511: Posting(freq=1, tfidf=4.107303706864606), 522: Posting(freq=2, tfidf=8.214607413729212), 673: Posting(freq=1, tfidf=4.107303706864606), 792: Posting(freq=1, tfidf=4.107303706864606), 798: Posting(freq=1, tfidf=4.107303706864606), 991: Posting(freq=1, tfidf=4.107303706864606), 1040: Posting(freq=1, tfidf=4.107303706864606), 1075: Posting(freq=1, tfidf=4.107303706864606), 1094: Posting(freq=1, tfidf=4.107303706864606), 1169: Posting(freq=1, tfidf=4.107303706864606), 1225: Posting(freq=4, tfidf=16.429214827458424), 1261: Posting(freq=2, tfidf=8.214607413729212), 1380: Posting(freq=1, tfidf=4.107303706864606), 1386: Posting(freq=2, tfidf=8.214607413729212)} and document frequency is 23
# the term is advisori, posting list is {314: Posting(freq=1, tfidf=6.54965074223381), 1385: Posting(freq=1, tfidf=6.54965074223381)} and document frequency is 2
# the term is advoc, posting list is {390: Posting(freq=1, tfidf=6.54965074223381), 592: Posting(freq=1, tfidf=6.54965074223381)} and document frequency is 2
# the term is aec, posting list is {830: Posting(freq=1, tfidf=6.54965074223381), 1055: Posting(freq=1, tfidf=6.54965074223381)} and document frequency is 2
# the term is aeolotrop, posting list is {1392: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is aerelast, posting list is {12: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is aerfoil, posting list is {798: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is aeroballist, posting list is {505: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# ...
# the term is xenon, posting list is {185: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is xiiiw, posting list is {578: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is yarymovych, posting list is {764: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is yaw, posting list is {42: Posting(freq=1, tfidf=3.716437398177594), 78: Posting(freq=2, tfidf=7.432874796355188), 205: Posting(freq=1, tfidf=3.716437398177594), 210: Posting(freq=6, tfidf=22.298624389065566), 229: Posting(freq=3, tfidf=11.149312194532783), 239: Posting(freq=2, tfidf=7.432874796355188), 333: Posting(freq=4, tfidf=14.865749592710376), 336: Posting(freq=1, tfidf=3.716437398177594), 368: Posting(freq=1, tfidf=3.716437398177594), 423: Posting(freq=3, tfidf=11.149312194532783), 435: Posting(freq=2, tfidf=7.432874796355188), 499: Posting(freq=1, tfidf=3.716437398177594), 539: Posting(freq=2, tfidf=7.432874796355188), 563: Posting(freq=1, tfidf=3.716437398177594), 564: Posting(freq=8, tfidf=29.731499185420752), 565: Posting(freq=5, tfidf=18.58218699088797), 566: Posting(freq=4, tfidf=14.865749592710376), 605: Posting(freq=1, tfidf=3.716437398177594), 755: Posting(freq=2, tfidf=7.432874796355188), 790: Posting(freq=5, tfidf=18.58218699088797), 792: Posting(freq=1, tfidf=3.716437398177594), 907: Posting(freq=3, tfidf=11.149312194532783), 922: Posting(freq=1, tfidf=3.716437398177594), 1005: Posting(freq=1, tfidf=3.716437398177594), 1110: Posting(freq=3, tfidf=11.149312194532783), 1144: Posting(freq=2, tfidf=7.432874796355188), 1159: Posting(freq=1, tfidf=3.716437398177594), 1192: Posting(freq=1, tfidf=3.716437398177594), 1213: Posting(freq=9, tfidf=33.44793658359835), 1231: Posting(freq=2, tfidf=7.432874796355188), 1306: Posting(freq=1, tfidf=3.716437398177594), 1307: Posting(freq=1, tfidf=3.716437398177594), 1309: Posting(freq=5, tfidf=18.58218699088797), 1310: Posting(freq=1, tfidf=3.716437398177594)} and document frequency is 34
# the term is year, posting list is {83: Posting(freq=1, tfidf=4.409584578737539), 91: Posting(freq=1, tfidf=4.409584578737539), 207: Posting(freq=1, tfidf=4.409584578737539), 262: Posting(freq=1, tfidf=4.409584578737539), 370: Posting(freq=1, tfidf=4.409584578737539), 645: Posting(freq=1, tfidf=4.409584578737539), 649: Posting(freq=1, tfidf=4.409584578737539), 658: Posting(freq=1, tfidf=4.409584578737539), 740: Posting(freq=1, tfidf=4.409584578737539), 743: Posting(freq=1, tfidf=4.409584578737539), 746: Posting(freq=1, tfidf=4.409584578737539), 760: Posting(freq=1, tfidf=4.409584578737539), 804: Posting(freq=1, tfidf=4.409584578737539), 825: Posting(freq=1, tfidf=4.409584578737539), 958: Posting(freq=1, tfidf=4.409584578737539), 1015: Posting(freq=1, tfidf=4.409584578737539), 1057: Posting(freq=1, tfidf=4.409584578737539)} and document frequency is 17
# the term is yeh, posting list is {981: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is yeild, posting list is {1366: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is yet, posting list is {19: Posting(freq=1, tfidf=4.470209200553974), 32: Posting(freq=1, tfidf=4.470209200553974), 153: Posting(freq=1, tfidf=4.470209200553974), 186: Posting(freq=1, tfidf=4.470209200553974), 201: Posting(freq=1, tfidf=4.470209200553974), 416: Posting(freq=1, tfidf=4.470209200553974), 552: Posting(freq=1, tfidf=4.470209200553974), 620: Posting(freq=1, tfidf=4.470209200553974), 622: Posting(freq=1, tfidf=4.470209200553974), 640: Posting(freq=2, tfidf=8.940418401107948), 663: Posting(freq=1, tfidf=4.470209200553974), 718: Posting(freq=1, tfidf=4.470209200553974), 933: Posting(freq=1, tfidf=4.470209200553974), 992: Posting(freq=1, tfidf=4.470209200553974), 1110: Posting(freq=1, tfidf=4.470209200553974), 1122: Posting(freq=1, tfidf=4.470209200553974)} and document frequency is 16
# the term is yield, posting list is {35: Posting(freq=1, tfidf=2.9523384816453646), 49: Posting(freq=1, tfidf=2.9523384816453646), 77: Posting(freq=1, tfidf=2.9523384816453646), 82: Posting(freq=2, tfidf=5.904676963290729), 118: Posting(freq=1, tfidf=2.9523384816453646), 149: Posting(freq=2, tfidf=5.904676963290729), 164: Posting(freq=2, tfidf=5.904676963290729), 165: Posting(freq=1, tfidf=2.9523384816453646), 191: Posting(freq=1, tfidf=2.9523384816453646), 193: Posting(freq=1, tfidf=2.9523384816453646), 201: Posting(freq=1, tfidf=2.9523384816453646), 218: Posting(freq=1, tfidf=2.9523384816453646), 267: Posting(freq=1, tfidf=2.9523384816453646), 274: Posting(freq=1, tfidf=2.9523384816453646), 348: Posting(freq=1, tfidf=2.9523384816453646), 391: Posting(freq=1, tfidf=2.9523384816453646), 403: Posting(freq=1, tfidf=2.9523384816453646), 421: Posting(freq=1, tfidf=2.9523384816453646), 434: Posting(freq=1, tfidf=2.9523384816453646), 448: Posting(freq=1, tfidf=2.9523384816453646), 449: Posting(freq=1, tfidf=2.9523384816453646), 454: Posting(freq=1, tfidf=2.9523384816453646), 467: Posting(freq=2, tfidf=5.904676963290729), 476: Posting(freq=1, tfidf=2.9523384816453646), 482: Posting(freq=1, tfidf=2.9523384816453646), 568: Posting(freq=1, tfidf=2.9523384816453646), 572: Posting(freq=1, tfidf=2.9523384816453646), 579: Posting(freq=1, tfidf=2.9523384816453646), 586: Posting(freq=1, tfidf=2.9523384816453646), 645: Posting(freq=1, tfidf=2.9523384816453646), 662: Posting(freq=1, tfidf=2.9523384816453646), 667: Posting(freq=1, tfidf=2.9523384816453646), 703: Posting(freq=1, tfidf=2.9523384816453646), 730: Posting(freq=1, tfidf=2.9523384816453646), 732: Posting(freq=1, tfidf=2.9523384816453646), 741: Posting(freq=1, tfidf=2.9523384816453646), 760: Posting(freq=1, tfidf=2.9523384816453646), 788: Posting(freq=2, tfidf=5.904676963290729), 818: Posting(freq=3, tfidf=8.857015444936094), 822: Posting(freq=2, tfidf=5.904676963290729), 830: Posting(freq=1, tfidf=2.9523384816453646), 831: Posting(freq=1, tfidf=2.9523384816453646), 907: Posting(freq=1, tfidf=2.9523384816453646), 917: Posting(freq=1, tfidf=2.9523384816453646), 928: Posting(freq=2, tfidf=5.904676963290729), 941: Posting(freq=1, tfidf=2.9523384816453646), 962: Posting(freq=1, tfidf=2.9523384816453646), 965: Posting(freq=1, tfidf=2.9523384816453646), 1015: Posting(freq=2, tfidf=5.904676963290729), 1027: Posting(freq=1, tfidf=2.9523384816453646), 1028: Posting(freq=1, tfidf=2.9523384816453646), 1053: Posting(freq=1, tfidf=2.9523384816453646), 1055: Posting(freq=1, tfidf=2.9523384816453646), 1068: Posting(freq=1, tfidf=2.9523384816453646), 1069: Posting(freq=1, tfidf=2.9523384816453646), 1070: Posting(freq=1, tfidf=2.9523384816453646), 1071: Posting(freq=1, tfidf=2.9523384816453646), 1112: Posting(freq=1, tfidf=2.9523384816453646), 1119: Posting(freq=1, tfidf=2.9523384816453646), 1121: Posting(freq=2, tfidf=5.904676963290729), 1134: Posting(freq=1, tfidf=2.9523384816453646), 1135: Posting(freq=3, tfidf=8.857015444936094), 1136: Posting(freq=1, tfidf=2.9523384816453646), 1137: Posting(freq=1, tfidf=2.9523384816453646), 1182: Posting(freq=1, tfidf=2.9523384816453646), 1216: Posting(freq=1, tfidf=2.9523384816453646), 1235: Posting(freq=1, tfidf=2.9523384816453646), 1239: Posting(freq=1, tfidf=2.9523384816453646), 1245: Posting(freq=1, tfidf=2.9523384816453646), 1265: Posting(freq=1, tfidf=2.9523384816453646), 1280: Posting(freq=1, tfidf=2.9523384816453646), 1300: Posting(freq=1, tfidf=2.9523384816453646), 1368: Posting(freq=1, tfidf=2.9523384816453646)} and document frequency is 73
# the term is york, posting list is {488: Posting(freq=1, tfidf=5.856503561673865), 830: Posting(freq=1, tfidf=5.856503561673865), 1036: Posting(freq=1, tfidf=5.856503561673865), 1055: Posting(freq=1, tfidf=5.856503561673865)} and document frequency is 4
# the term is young, posting list is {392: Posting(freq=1, tfidf=5.856503561673865), 567: Posting(freq=1, tfidf=5.856503561673865), 611: Posting(freq=1, tfidf=5.856503561673865), 857: Posting(freq=1, tfidf=5.856503561673865)} and document frequency is 4
# the term is yuan, posting list is {1175: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is z, posting list is {148: Posting(freq=1, tfidf=5.4510384535657), 259: Posting(freq=1, tfidf=5.4510384535657), 499: Posting(freq=2, tfidf=10.9020769071314), 734: Posting(freq=2, tfidf=10.9020769071314), 738: Posting(freq=4, tfidf=21.8041538142628), 1173: Posting(freq=5, tfidf=27.2551922678285)} and document frequency is 6
# the term is zakkay, posting list is {668: Posting(freq=1, tfidf=6.54965074223381), 1204: Posting(freq=1, tfidf=6.54965074223381)} and document frequency is 2
# the term is zamm, posting list is {328: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is zbrozek, posting list is {902: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is zero, posting list is {18: Posting(freq=1, tfidf=2.1069994857434935), 27: Posting(freq=2, tfidf=4.213998971486987), 32: Posting(freq=1, tfidf=2.1069994857434935), 44: Posting(freq=1, tfidf=2.1069994857434935), 51: Posting(freq=2, tfidf=4.213998971486987), 54: Posting(freq=1, tfidf=2.1069994857434935), 56: Posting(freq=2, tfidf=4.213998971486987), 57: Posting(freq=1, tfidf=2.1069994857434935), 59: Posting(freq=1, tfidf=2.1069994857434935), 62: Posting(freq=4, tfidf=8.427997942973974), 94: Posting(freq=2, tfidf=4.213998971486987), 96: Posting(freq=1, tfidf=2.1069994857434935), 101: Posting(freq=1, tfidf=2.1069994857434935), 104: Posting(freq=1, tfidf=2.1069994857434935), 110: Posting(freq=1, tfidf=2.1069994857434935), 122: Posting(freq=3, tfidf=6.3209984572304805), 124: Posting(freq=1, tfidf=2.1069994857434935), 128: Posting(freq=1, tfidf=2.1069994857434935), 131: Posting(freq=1, tfidf=2.1069994857434935), 132: Posting(freq=1, tfidf=2.1069994857434935), 133: Posting(freq=1, tfidf=2.1069994857434935), 134: Posting(freq=1, tfidf=2.1069994857434935), 145: Posting(freq=1, tfidf=2.1069994857434935), 147: Posting(freq=2, tfidf=4.213998971486987), 157: Posting(freq=1, tfidf=2.1069994857434935), 165: Posting(freq=1, tfidf=2.1069994857434935), 168: Posting(freq=1, tfidf=2.1069994857434935), 174: Posting(freq=1, tfidf=2.1069994857434935), 179: Posting(freq=1, tfidf=2.1069994857434935), 188: Posting(freq=1, tfidf=2.1069994857434935), 193: Posting(freq=1, tfidf=2.1069994857434935), 199: Posting(freq=1, tfidf=2.1069994857434935), 203: Posting(freq=2, tfidf=4.213998971486987), 206: Posting(freq=2, tfidf=4.213998971486987), 214: Posting(freq=1, tfidf=2.1069994857434935), 225: Posting(freq=3, tfidf=6.3209984572304805), 228: Posting(freq=1, tfidf=2.1069994857434935), 229: Posting(freq=1, tfidf=2.1069994857434935), 231: Posting(freq=1, tfidf=2.1069994857434935), 232: Posting(freq=1, tfidf=2.1069994857434935), 234: Posting(freq=4, tfidf=8.427997942973974), 235: Posting(freq=1, tfidf=2.1069994857434935), 240: Posting(freq=2, tfidf=4.213998971486987), 247: Posting(freq=1, tfidf=2.1069994857434935), 248: Posting(freq=2, tfidf=4.213998971486987), 250: Posting(freq=1, tfidf=2.1069994857434935), 252: Posting(freq=1, tfidf=2.1069994857434935), 282: Posting(freq=2, tfidf=4.213998971486987), 283: Posting(freq=1, tfidf=2.1069994857434935), 289: Posting(freq=1, tfidf=2.1069994857434935), 299: Posting(freq=1, tfidf=2.1069994857434935), 304: Posting(freq=1, tfidf=2.1069994857434935), 306: Posting(freq=1, tfidf=2.1069994857434935), 310: Posting(freq=1, tfidf=2.1069994857434935), 314: Posting(freq=3, tfidf=6.3209984572304805), 318: Posting(freq=1, tfidf=2.1069994857434935), 324: Posting(freq=1, tfidf=2.1069994857434935), 325: Posting(freq=1, tfidf=2.1069994857434935), 326: Posting(freq=1, tfidf=2.1069994857434935), 334: Posting(freq=1, tfidf=2.1069994857434935), 338: Posting(freq=2, tfidf=4.213998971486987), 348: Posting(freq=1, tfidf=2.1069994857434935), 352: Posting(freq=1, tfidf=2.1069994857434935), 364: Posting(freq=2, tfidf=4.213998971486987), 380: Posting(freq=1, tfidf=2.1069994857434935), 399: Posting(freq=2, tfidf=4.213998971486987), 406: Posting(freq=2, tfidf=4.213998971486987), 413: Posting(freq=1, tfidf=2.1069994857434935), 423: Posting(freq=2, tfidf=4.213998971486987), 452: Posting(freq=1, tfidf=2.1069994857434935), 458: Posting(freq=1, tfidf=2.1069994857434935), 459: Posting(freq=1, tfidf=2.1069994857434935), 465: Posting(freq=2, tfidf=4.213998971486987), 469: Posting(freq=1, tfidf=2.1069994857434935), 474: Posting(freq=1, tfidf=2.1069994857434935), 478: Posting(freq=5, tfidf=10.534997428717467), 479: Posting(freq=2, tfidf=4.213998971486987), 489: Posting(freq=1, tfidf=2.1069994857434935), 492: Posting(freq=1, tfidf=2.1069994857434935), 499: Posting(freq=1, tfidf=2.1069994857434935), 520: Posting(freq=1, tfidf=2.1069994857434935), 521: Posting(freq=1, tfidf=2.1069994857434935), 522: Posting(freq=1, tfidf=2.1069994857434935), 528: Posting ...
# the term is zeroth, posting list is {94: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is zhukhovitskii, posting list is {270: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is zone, posting list is {14: Posting(freq=2, tfidf=9.355697130664437), 126: Posting(freq=2, tfidf=9.355697130664437), 167: Posting(freq=1, tfidf=4.677848565332218), 218: Posting(freq=1, tfidf=4.677848565332218), 243: Posting(freq=3, tfidf=14.033545695996654), 455: Posting(freq=1, tfidf=4.677848565332218), 828: Posting(freq=1, tfidf=4.677848565332218), 960: Posting(freq=2, tfidf=9.355697130664437), 1072: Posting(freq=3, tfidf=14.033545695996654), 1135: Posting(freq=1, tfidf=4.677848565332218), 1167: Posting(freq=1, tfidf=4.677848565332218), 1268: Posting(freq=1, tfidf=4.677848565332218), 1318: Posting(freq=1, tfidf=4.677848565332218)} and document frequency is 13
# the term is zoom, posting list is {374: Posting(freq=2, tfidf=14.485595845587511)} and document frequency is 1
# the term is zuk, posting list is {890: Posting(freq=1, tfidf=7.242797922793756)} and document frequency is 1
# the term is zurich, posting list is {792: Posting(freq=1, tfidf=6.54965074223381), 1137: Posting(freq=1, tfidf=6.54965074223381)} and document frequency is 2

# %%
#------------------------------------------------------- Execute this if mapping is not found.------------------------------
'''
map_doc_queries = mapping(cran_queries, cran_docs)

# save map_doc_queries as pickle
import pickle
with open('map_doc_queries.pkl', 'wb') as f:
    pickle.dump(map_doc_queries, f)'''

# read map_doc_queries.pkl
with open('map_doc_queries.pkl', 'rb') as f:
    mapped_data = pickle.load(f)
    
################################## BM25 ##################################
model = BM25(inv_index, mapped_data)
ranking = {qid: model.rank(qid, query) for qid, query in cran_queries.items()}

filename = r"./results/bm25_ranking.txt"  
with open(filename, "w") as file:
    for qid, rankings in ranking.items():
        for rank, (docid, score) in enumerate(rankings.items(), start=1):
            file.write(f"{qid} Q0 {docid} {rank} {score:.4f} RUN_ID\n")
            
################################## VSM ##################################
# run VSM model
model = VSM(inv_index, mapped_data)

# loop through each query and perform ranking
ranking = {qid: model.rank(qid, query) for qid, query in cran_queries.items()}

# save the ranking in a text file.
filename = r"./results/vsm_ranking.txt"
with open(filename, "w") as file:
    for qid, rankings in ranking.items():
        for rank, (docid, score) in enumerate(rankings.items(), start=1):
            # select only top 100 ranks
            file.write(f"{qid} Q0 {docid} {rank} {score:.4f} RUN_ID\n")
            

################################## Query Likelihood with Laplace smoothing language Model ##################################
# run Language model

model = LanguageModel(inv_index, mapped_data)

# perform ranking
ranking = {qid: model.rank(qid, query) for qid, query in cran_queries.items()}

# save the result to a file as query_id iter <space> document_id <space> rank <space> similarity <space> run_id
filename = r"./results/language_model.txt"
with open(filename, "w") as file:
    for qid, rankings in ranking.items():
        for rank, (docid, score) in enumerate(rankings.items(), start=1):
            file.write(f"{qid} Q0 {docid} {rank} {score:.4f} RUN_ID\n")
